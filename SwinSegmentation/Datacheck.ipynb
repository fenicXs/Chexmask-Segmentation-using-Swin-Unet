# %%
data_dir = "/scratch/tprasad6/my_mimic_project/vinDR/vinbigdata"

# %%
import os


# Get a list of all entries (files and subdirectories) in the folder
contents = os.listdir(data_dir)

# Print each item in the folder
print(f"Contents of '{data_dir}':")
for item in contents:
    print(item)
# Out:
# Contents of '/scratch/tprasad6/my_mimic_project/vinDR/vinbigdata':
# train
# sample_submission.csv
# test
# train.csv

# %%
contents
# Out:
# ['train', 'sample_submission.csv', 'test', 'train.csv']

# %%
train_f = os.listdir(f"{data_dir}/train")

# %%
len(train_f)
# Out:
# 15000

# %%
import pandas as pd

# %%
df = pd.read_csv(f"/scratch/pkrish52/CheXmask Dataset/Preprocessed/VinDr-CXR.csv")
